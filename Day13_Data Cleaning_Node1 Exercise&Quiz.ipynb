# %%
import pandas as pd

# %%
data=pd.read_csv('titanic.csv')

# %%
data.head()
# Out:
#    Pclass                                               Name   Gendr   Age  \
# 0       3                            Braund, Mr. Owen Harris    male  22.0
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2       3                             Heikkinen, Miss. Laina  female  26.0
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   NaN
# 4       3                           Allen, Mr. William Henry    male  35.0
#
#    SibSp  Parch            Ticket Embarked  Survived ticket_date
# 0      1      0         A/5 21171        S         0  1912-01-12
# 1      1      0          PC 17599        C         1  1912-03-29
# 2      0      0  STON/O2. 3101282        S         1  1912-02-23
# 3      1      0            113803        S         1  1912-03-28
# 4      0      0            373450        S         0  1912-04-03

# %%
data.tail()
# Out:
#      Pclass                                      Name   Gendr   Age  SibSp  \
# 880       2                     Montvila, Rev. Juozas    male  27.0      0
# 881       1              Graham, Miss. Margaret Edith  female  19.0      0
# 882       3  Johnston, Miss. Catherine Helen "Carrie"  female  28.0      1
# 883       1                     Behr, Mr. Karl Howell    male  26.0      0
# 884       3                       Dooley, Mr. Patrick    male  32.0      0
#
#      Parch      Ticket Embarked  Survived ticket_date
# 880      0      211536        S         0  1912-01-29
# 881      0      112053        S         1  1912-03-30
# 882      2  W./C. 6607        S         0  1912-04-07
# 883      0      111369        C         1  1912-03-01
# 884      0      370376        Q         0  1912-03-05

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 885 entries, 0 to 884
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Pclass       885 non-null    int64
#  1   Name         885 non-null    object
#  2   Gendr        885 non-null    object
#  3   Age          879 non-null    float64
#  4   SibSp        885 non-null    int64
#  5   Parch        885 non-null    int64
#  6   Ticket       885 non-null    object
#  7   Embarked     883 non-null    object
#  8   Survived     885 non-null    int64
#  9   ticket_date  885 non-null    object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 69.3+ KB

# %%
data.describe()
# Out:
#            Pclass         Age       SibSp       Parch    Survived
# count  885.000000  879.000000  885.000000  885.000000  885.000000
# mean     2.311864   29.679181    0.525424    0.377401    0.377401
# std      0.836069   13.559664    1.109746    0.805768    0.485011
# min      1.000000    1.000000    0.000000    0.000000    0.000000
# 25%      2.000000   22.000000    0.000000    0.000000    0.000000
# 50%      3.000000   28.000000    0.000000    0.000000    0.000000
# 75%      3.000000   35.000000    1.000000    0.000000    1.000000
# max      3.000000  145.000000    8.000000    6.000000    1.000000

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 880    False
# 881    False
# 882    False
# 883    False
# 884    False
# Length: 885, dtype: bool

# %%
data[data.duplicated()]
# Out:
#      Pclass                           Name   Gendr   Age  SibSp  Parch  \
# 25        3  Palsson, Miss. Torborg Danira  female   8.0      3      1
# 632       3             Skoog, Miss. Mabel  female   9.0      3      2
# 714       1  Endres, Miss. Caroline Louise  female  38.0      0      0
#
#        Ticket Embarked  Survived ticket_date
# 25     349909        S         0  1912-03-14
# 632    347088        S         0  1912-03-16
# 714  PC 17757        C         1  1912-03-14

# %%
data[data['Name']=='Palsson, Miss. Torborg Danira']
# Out:
#     Pclass                           Name   Gendr  Age  SibSp  Parch  Ticket  \
# 24       3  Palsson, Miss. Torborg Danira  female  8.0      3      1  349909
# 25       3  Palsson, Miss. Torborg Danira  female  8.0      3      1  349909
#
#    Embarked  Survived ticket_date
# 24        S         0  1912-03-14
# 25        S         0  1912-03-14

# %%
data=data.drop_duplicates()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 882 entries, 0 to 884
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Pclass       882 non-null    int64
#  1   Name         882 non-null    object
#  2   Gendr        882 non-null    object
#  3   Age          876 non-null    float64
#  4   SibSp        882 non-null    int64
#  5   Parch        882 non-null    int64
#  6   Ticket       882 non-null    object
#  7   Embarked     880 non-null    object
#  8   Survived     882 non-null    int64
#  9   ticket_date  882 non-null    object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 75.8+ KB

# %%
data
# Out:
#      Pclass                                               Name   Gendr   Age  \
# 0         3                            Braund, Mr. Owen Harris    male  22.0
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2         3                             Heikkinen, Miss. Laina  female  26.0
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   NaN
# 4         3                           Allen, Mr. William Henry    male  35.0
# ..      ...                                                ...     ...   ...
# 880       2                              Montvila, Rev. Juozas    male  27.0
# 881       1                       Graham, Miss. Margaret Edith  female  19.0
# 882       3           Johnston, Miss. Catherine Helen "Carrie"  female  28.0
# 883       1                              Behr, Mr. Karl Howell    male  26.0
# 884       3                                Dooley, Mr. Patrick    male  32.0
#
# ...

# %%
data.drop('Name', axis=1)
# Out:
#      Pclass   Gendr   Age  SibSp  Parch            Ticket Embarked  Survived  \
# 0         3    male  22.0      1      0         A/5 21171        S         0
# 1         1  female  38.0      1      0          PC 17599        C         1
# 2         3  female  26.0      0      0  STON/O2. 3101282        S         1
# 3         1  female   NaN      1      0            113803        S         1
# 4         3    male  35.0      0      0            373450        S         0
# ..      ...     ...   ...    ...    ...               ...      ...       ...
# 880       2    male  27.0      0      0            211536        S         0
# 881       1  female  19.0      0      0            112053        S         1
# 882       3  female  28.0      1      2        W./C. 6607        S         0
# 883       1    male  26.0      0      0            111369        C         1
# 884       3    male  32.0      0      0            370376        Q         0
#
#     ticket_date
# 0    1912-01-12
# ...

# %%
data.drop('Name', axis=1, inplace=True)

# %%
data.head()
# Out:
#    Pclass   Gendr   Age  SibSp  Parch            Ticket Embarked  Survived  \
# 0       3    male  22.0      1      0         A/5 21171        S         0
# 1       1  female  38.0      1      0          PC 17599        C         1
# 2       3  female  26.0      0      0  STON/O2. 3101282        S         1
# 3       1  female   NaN      1      0            113803        S         1
# 4       3    male  35.0      0      0            373450        S         0
#
#   ticket_date
# 0  1912-01-12
# 1  1912-03-29
# 2  1912-02-23
# 3  1912-03-28
# 4  1912-04-03

# %%
data.dropna()
# Out:
#      Pclass   Gendr   Age  SibSp  Parch            Ticket Embarked  Survived  \
# 0         3    male  22.0      1      0         A/5 21171        S         0
# 1         1  female  38.0      1      0          PC 17599        C         1
# 2         3  female  26.0      0      0  STON/O2. 3101282        S         1
# 4         3    male  35.0      0      0            373450        S         0
# 5         3    male  28.0      0      0            330877        Q         0
# ..      ...     ...   ...    ...    ...               ...      ...       ...
# 880       2    male  27.0      0      0            211536        S         0
# 881       1  female  19.0      0      0            112053        S         1
# 882       3  female  28.0      1      2        W./C. 6607        S         0
# 883       1    male  26.0      0      0            111369        C         1
# 884       3    male  32.0      0      0            370376        Q         0
#
#     ticket_date
# 0    1912-01-12
# ...

# %%
data.dropna(subset=['Embarked'])
# Out:
#      Pclass   Gendr   Age  SibSp  Parch            Ticket Embarked  Survived  \
# 0         3    male  22.0      1      0         A/5 21171        S         0
# 1         1  female  38.0      1      0          PC 17599        C         1
# 2         3  female  26.0      0      0  STON/O2. 3101282        S         1
# 3         1  female   NaN      1      0            113803        S         1
# 4         3    male  35.0      0      0            373450        S         0
# ..      ...     ...   ...    ...    ...               ...      ...       ...
# 880       2    male  27.0      0      0            211536        S         0
# 881       1  female  19.0      0      0            112053        S         1
# 882       3  female  28.0      1      2        W./C. 6607        S         0
# 883       1    male  26.0      0      0            111369        C         1
# 884       3    male  32.0      0      0            370376        Q         0
#
#     ticket_date
# 0    1912-01-12
# ...

# %%
dt_data=data.drop(['Ticket','ticket_date'], axis=1)
dt_data
# Out:
#      Pclass   Gendr   Age  SibSp  Parch Embarked  Survived
# 0         3    male  22.0      1      0        S         0
# 1         1  female  38.0      1      0        C         1
# 2         3  female  26.0      0      0        S         1
# 3         1  female   NaN      1      0        S         1
# 4         3    male  35.0      0      0        S         0
# ..      ...     ...   ...    ...    ...      ...       ...
# 880       2    male  27.0      0      0        S         0
# 881       1  female  19.0      0      0        S         1
# 882       3  female  28.0      1      2        S         0
# 883       1    male  26.0      0      0        C         1
# 884       3    male  32.0      0      0        Q         0
#
# [882 rows x 7 columns]

# %%
#마지막 행을 출력
data.loc[884]
# Out:
# Pclass                  3
# Gendr                male
# Age                  32.0
# SibSp                   0
# Parch                   0
# Ticket             370376
# Embarked                Q
# Survived                0
# ticket_date    1912-03-05
# Name: 884, dtype: object

# %%
#Embarked의 결측치 출력
data[data['Embarked'].isna()]
# Out:
#      Pclass   Gendr   Age  SibSp  Parch    Ticket Embarked  Survived  \
# 15        2  female  55.0      0      0    248706      NaN         1
# 322       3    male  28.0      8      2  CA. 2343      NaN         0
#
#     ticket_date
# 15   1912-03-05
# 322  1912-03-26

# %%
# Age의 값을 ascending으로 정렬
data['Age'].sort_values()
# Out:
# 785    1.0
# 171    1.0
# 379    1.0
# 163    1.0
# 182    1.0
#       ...
# 106    NaN
# 156    NaN
# 185    NaN
# 213    NaN
# 241    NaN
# Name: Age, Length: 882, dtype: float64

# %%
# Age의 NaN결측치를 median값으로 바꾸기
data['Age']=data['Age'].fillna(data['Age'].median())

# %%
data['Age'].sort_values()
# Out:
# 379      1.0
# 785      1.0
# 171      1.0
# 823      1.0
# 182      1.0
#        ...
# 490     71.0
# 845     74.0
# 627     80.0
# 279     97.0
# 321    145.0
# Name: Age, Length: 882, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.displot(data['SibSp'])

# %%
sns.displot(data['Age'])

# %%
sns.scatterplot(x=data.index, y=data['Age'])
# Out:
# <AxesSubplot:ylabel='Age'>

# %%
sns.scatterplot(x=data.index, y=data['SibSp'])
# Out:
# <AxesSubplot:ylabel='SibSp'>

# %%
sns.boxplot(data['Age'])
# Out:
# /opt/conda/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %%
sns.boxplot(data['SibSp'])
# Out:
# /opt/conda/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SibSp'>

# %%
# Age에서 outlier 제거 (145살)
data = data[data['Age'] <= 100]

# 내 코드.... data.drop(age>100)

# %%
#1-4. Quiz. 데이터의 'Age' 컬럼에 있는 모든 값에 대해, 70세 초과인 경우 그 값을 70으로 변경하고 그렇지 않은 경우 원래의 값을 유지하는 코드를 적어주세요. 
#(참고: lambda 함수를 활용하고, 'Age' 컬럼이 내림차순으로 보일 수 있도록 정렬해 주세요.)

data['Age'].apply(lambda x: 70 if x>70 else x).sort_values(ascending=False)

#data.replace(data['Age'], lambda x: 70 < 70, x).sort_values()
# Out:
# 95     70.0
# 490    70.0
# 845    70.0
# 279    70.0
# 115    70.0
#        ...
# 163     1.0
# 379     1.0
# 182     1.0
# 823     1.0
# 785     1.0
# Name: Age, Length: 881, dtype: float64

# %%
# 컬럼 이름 바꾸기
data=data.rename({'Gendr':'Gender'},axis=1)
data
# Out:
#      Pclass  Gender   Age  SibSp  Parch            Ticket Embarked  Survived  \
# 0         3    male  22.0      1      0         A/5 21171        S         0
# 1         1  female  38.0      1      0          PC 17599        C         1
# 2         3  female  26.0      0      0  STON/O2. 3101282        S         1
# 3         1  female  28.0      1      0            113803        S         1
# 4         3    male  35.0      0      0            373450        S         0
# ..      ...     ...   ...    ...    ...               ...      ...       ...
# 880       2    male  27.0      0      0            211536        S         0
# 881       1  female  19.0      0      0            112053        S         1
# 882       3  female  28.0      1      2        W./C. 6607        S         0
# 883       1    male  26.0      0      0            111369        C         1
# 884       3    male  32.0      0      0            370376        Q         0
#
#     ticket_date
# 0    1912-01-12
# ...

# %%
data.rename({0:'a', 1:'b', 2:'c'})
# Out:
#      Pclass  Gender   Age  SibSp  Parch            Ticket Embarked  Survived  \
# a         3    male  22.0      1      0         A/5 21171        S         0
# b         1  female  38.0      1      0          PC 17599        C         1
# c         3  female  26.0      0      0  STON/O2. 3101282        S         1
# 3         1  female  28.0      1      0            113803        S         1
# 4         3    male  35.0      0      0            373450        S         0
# ..      ...     ...   ...    ...    ...               ...      ...       ...
# 880       2    male  27.0      0      0            211536        S         0
# 881       1  female  19.0      0      0            112053        S         1
# 882       3  female  28.0      1      2        W./C. 6607        S         0
# 883       1    male  26.0      0      0            111369        C         1
# 884       3    male  32.0      0      0            370376        Q         0
#
#     ticket_date
# a    1912-01-12
# ...

# %%
# replace해서  series로 보여주는 method
data['Embarked'].replace({'S':'Southampton','C':'Cherbourg','Q':'Queenstown'})
# Out:
# 0      Southampton
# 1        Cherbourg
# 2      Southampton
# 3      Southampton
# 4      Southampton
#           ...
# 880    Southampton
# 881    Southampton
# 882    Southampton
# 883      Cherbourg
# 884     Queenstown
# Name: Embarked, Length: 881, dtype: object

# %%
# replace해서  data frame으로 보여주는 method
data.replace({'S':'Southampton','C':'Cherbourg','Q':'Queenstown'})
# Out:
#      Pclass  Gender   Age  SibSp  Parch            Ticket     Embarked  \
# 0         3    male  22.0      1      0         A/5 21171  Southampton
# 1         1  female  38.0      1      0          PC 17599    Cherbourg
# 2         3  female  26.0      0      0  STON/O2. 3101282  Southampton
# 3         1  female  28.0      1      0            113803  Southampton
# 4         3    male  35.0      0      0            373450  Southampton
# ..      ...     ...   ...    ...    ...               ...          ...
# 880       2    male  27.0      0      0            211536  Southampton
# 881       1  female  19.0      0      0            112053  Southampton
# 882       3  female  28.0      1      2        W./C. 6607  Southampton
# 883       1    male  26.0      0      0            111369    Cherbourg
# 884       3    male  32.0      0      0            370376   Queenstown
#
#      Survived ticket_date
# 0           0  1912-01-12
# 1           1  1912-03-29
# 2           1  1912-02-23
# ...

# %%
#map은 series에서만.  함수function을 넣어도 작동 male-4, female-6
data['Gender'].map(len)
# Out:
# 0      4
# 1      6
# 2      6
# 3      6
# 4      4
#       ..
# 880    4
# 881    6
# 882    6
# 883    4
# 884    4
# Name: Gender, Length: 881, dtype: int64

# %%
data.replace({0:999})
# Out:
#      Pclass  Gender   Age  SibSp  Parch            Ticket Embarked  Survived  \
# 0         3    male  22.0      1    999         A/5 21171        S       999
# 1         1  female  38.0      1    999          PC 17599        C         1
# 2         3  female  26.0    999    999  STON/O2. 3101282        S         1
# 3         1  female  28.0      1    999            113803        S         1
# 4         3    male  35.0    999    999            373450        S       999
# ..      ...     ...   ...    ...    ...               ...      ...       ...
# 880       2    male  27.0    999    999            211536        S       999
# 881       1  female  19.0    999    999            112053        S         1
# 882       3  female  28.0      1      2        W./C. 6607        S       999
# 883       1    male  26.0    999    999            111369        C         1
# 884       3    male  32.0    999    999            370376        Q       999
#
#     ticket_date
# 0    1912-01-12
# ...

# %%
# apply는 series, data frame에 둘 다 쓸 수 있음.  length는 행갯수
data.apply(len)
# Out:
# Pclass         881
# Gender         881
# Age            881
# SibSp          881
# Parch          881
# Ticket         881
# Embarked       881
# Survived       881
# ticket_date    881
# dtype: int64

# %%
# 1-4. 데이터의 'Age' 컬럼에 있는 모든 값에 대해, 70세 초과인 경우 그 값을 70으로 변경하고 그렇지 않은 경우 원래의 값을 유지하는 코드를 적어주세요. 
#(참고: lambda 함수를 활용하고, 'Age' 컬럼이 내림차순으로 보일 수 있도록 정렬해 주세요.)

data['Age'].apply(lambda x: 70 if x > 70 else x).sort_values(ascending=False)
# Out:
# 95     70.0
# 490    70.0
# 845    70.0
# 279    70.0
# 115    70.0
#        ...
# 163     1.0
# 379     1.0
# 182     1.0
# 823     1.0
# 785     1.0
# Name: Age, Length: 881, dtype: float64

# %%
#1-5. Quiz. 'Gendr' 컬럼의 이름을 'Gender'로 바꾸고, 2) 'male'을 '0', 'female'을 '1'로 바꾸는 코드를 적어 보세요.

data=data.rename({'Gendr':'Gender'}, axis=1)
data.replace({'male': '0', 'female': '1'})
# Out:
#      Pclass Gender   Age  SibSp  Parch            Ticket Embarked  Survived  \
# 0         3      0  22.0      1      0         A/5 21171        S         0
# 1         1      1  38.0      1      0          PC 17599        C         1
# 2         3      1  26.0      0      0  STON/O2. 3101282        S         1
# 3         1      1  28.0      1      0            113803        S         1
# 4         3      0  35.0      0      0            373450        S         0
# ..      ...    ...   ...    ...    ...               ...      ...       ...
# 880       2      0  27.0      0      0            211536        S         0
# 881       1      1  19.0      0      0            112053        S         1
# 882       3      1  28.0      1      2        W./C. 6607        S         0
# 883       1      0  26.0      0      0            111369        C         1
# 884       3      0  32.0      0      0            370376        Q         0
#
#     ticket_date
# 0    1912-01-12
# 1    1912-03-29
# ...

# %%
from datetime import datetime

# %%
sample_date=datetime.strptime('2023-01-01','%Y-%m-%d')

# %%
datetime.strftime(sample_date, '%Y-%m-%d')
# Out:
# '2023-01-01'

# %%
sample_date.year
# Out:
# 2023

# %%
next_date=datetime.strptime('2023-05-01','%Y-%m-%d')

# %%
next_date - sample_date
# Out:
# datetime.timedelta(days=120)

# %%
pd.to_datetime(data['ticket_date'])
# Out:
# 0     1912-01-12
# 1     1912-03-29
# 2     1912-02-23
# 3     1912-03-28
# 4     1912-04-03
#          ...
# 880   1912-01-29
# 881   1912-03-30
# 882   1912-04-07
# 883   1912-03-01
# 884   1912-03-05
# Name: ticket_date, Length: 881, dtype: datetime64[ns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 881 entries, 0 to 884
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Pclass       881 non-null    int64
#  1   Gender       881 non-null    object
#  2   Age          881 non-null    float64
#  3   SibSp        881 non-null    int64
#  4   Parch        881 non-null    int64
#  5   Ticket       881 non-null    object
#  6   Embarked     879 non-null    object
#  7   Survived     881 non-null    int64
#  8   ticket_date  881 non-null    object
# dtypes: float64(1), int64(4), object(4)
# memory usage: 101.1+ KB

# %%
data['ticket_date']=pd.to_datetime(data['ticket_date'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 881 entries, 0 to 884
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Pclass       881 non-null    int64
#  1   Gender       881 non-null    object
#  2   Age          881 non-null    float64
#  3   SibSp        881 non-null    int64
#  4   Parch        881 non-null    int64
#  5   Ticket       881 non-null    object
#  6   Embarked     879 non-null    object
#  7   Survived     881 non-null    int64
#  8   ticket_date  881 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(4), object(3)
# memory usage: 101.1+ KB

# %%
data['ticket_date'].dt.year
# Out:
# 0      1912
# 1      1912
# 2      1912
# 3      1912
# 4      1912
#        ...
# 880    1912
# 881    1912
# 882    1912
# 883    1912
# 884    1912
# Name: ticket_date, Length: 881, dtype: int64

# %%
acc=datetime.strptime('1912-04-15','%Y-%m-%d')

# %%
data['buy_before']=acc-data['ticket_date']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 881 entries, 0 to 884
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Pclass       881 non-null    int64
#  1   Gender       881 non-null    object
#  2   Age          881 non-null    float64
#  3   SibSp        881 non-null    int64
#  4   Parch        881 non-null    int64
#  5   Ticket       881 non-null    object
#  6   Embarked     879 non-null    object
#  7   Survived     881 non-null    int64
#  8   ticket_date  881 non-null    datetime64[ns]
#  9   buy_before   881 non-null    timedelta64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(4), object(3), timedelta64[ns](1)
# memory usage: 108.0+ KB

# %%
data.head()
# Out:
#    Pclass  Gender   Age  SibSp  Parch            Ticket Embarked  Survived  \
# 0       3    male  22.0      1      0         A/5 21171        S         0
# 1       1  female  38.0      1      0          PC 17599        C         1
# 2       3  female  26.0      0      0  STON/O2. 3101282        S         1
# 3       1  female  28.0      1      0            113803        S         1
# 4       3    male  35.0      0      0            373450        S         0
#
#   ticket_date buy_before
# 0  1912-01-12    94 days
# 1  1912-03-29    17 days
# 2  1912-02-23    52 days
# 3  1912-03-28    18 days
# 4  1912-04-03    12 days

# %%
data['buy_before'].dt.days
# Out:
# 0      94
# 1      17
# 2      52
# 3      18
# 4      12
#        ..
# 880    77
# 881    16
# 882     8
# 883    45
# 884    41
# Name: buy_before, Length: 881, dtype: int64

# %%
data['buy_before']=data['buy_before'].dt.days

# %%
data.head()
# Out:
#    Pclass  Gender   Age  SibSp  Parch            Ticket Embarked  Survived  \
# 0       3    male  22.0      1      0         A/5 21171        S         0
# 1       1  female  38.0      1      0          PC 17599        C         1
# 2       3  female  26.0      0      0  STON/O2. 3101282        S         1
# 3       1  female  28.0      1      0            113803        S         1
# 4       3    male  35.0      0      0            373450        S         0
#
#   ticket_date  buy_before
# 0  1912-01-12          94
# 1  1912-03-29          17
# 2  1912-02-23          52
# 3  1912-03-28          18
# 4  1912-04-03          12

# %%
data['buy_before']+10
# Out:
# 0      104
# 1       27
# 2       62
# 3       28
# 4       22
#       ...
# 880     87
# 881     26
# 882     18
# 883     55
# 884     51
# Name: buy_before, Length: 881, dtype: int64

# %%
from datetime import datetime
startdate=datetime.strptime('2022-11-24','%Y-%m-%d')
enddate=datetime.strptime('2023-03-15','%Y-%m-%d')
enddate-startdate
# Out:
# datetime.timedelta(days=111)

# %%
data['ticket_date']=pd.to_datetime(data['ticket_date'])
acc_date=datetime.strptime('1912-04-15','%Y-%m-%d')
acc_date - data['ticket_date']
# Out:
# 0     94 days
# 1     17 days
# 2     52 days
# 3     18 days
# 4     12 days
#         ...
# 880   77 days
# 881   16 days
# 882    8 days
# 883   45 days
# 884   41 days
# Name: ticket_date, Length: 881, dtype: timedelta64[ns]

# %%
#1-8 Quiz 1. titanic_df 라는 이름으로 data/titanic.csv 불러오기
titanic_df=pd.read_csv('data/titanic.csv')

# %%
# 상위 15줄의 데이터 확인하기
titanic_df.head(15)
# Out:
#     Pclass                                               Name   Gendr   Age  \
# 0        3                            Braund, Mr. Owen Harris    male  22.0
# 1        1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2        3                             Heikkinen, Miss. Laina  female  26.0
# 3        1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   NaN
# 4        3                           Allen, Mr. William Henry    male  35.0
# 5        3                                   Moran, Mr. James    male  28.0
# 6        1                            McCarthy, Mr. Timothy J    male  54.0
# 7        3                     Palsson, Master. Gosta Leonard    male   2.0
# 8        3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9        2                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 10       3                    Sandstrom, Miss. Marguerite Rut  female   4.0
# ...

# %%
# info 펑션으로 데이터 변수들 살펴보기
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 885 entries, 0 to 884
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Pclass       885 non-null    int64
#  1   Name         885 non-null    object
#  2   Gendr        885 non-null    object
#  3   Age          879 non-null    float64
#  4   SibSp        885 non-null    int64
#  5   Parch        885 non-null    int64
#  6   Ticket       885 non-null    object
#  7   Embarked     883 non-null    object
#  8   Survived     885 non-null    int64
#  9   ticket_date  885 non-null    object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 69.3+ KB

# %%
# 위의 코드에서 확인한 결과, Name 변수의 Data Type은?
#object

# %%
# describe로 데이터의 통계적 정보 확인하기
titanic_df.describe()
# Out:
#            Pclass         Age       SibSp       Parch    Survived
# count  885.000000  879.000000  885.000000  885.000000  885.000000
# mean     2.311864   29.679181    0.525424    0.377401    0.377401
# std      0.836069   13.559664    1.109746    0.805768    0.485011
# min      1.000000    1.000000    0.000000    0.000000    0.000000
# 25%      2.000000   22.000000    0.000000    0.000000    0.000000
# 50%      3.000000   28.000000    0.000000    0.000000    0.000000
# 75%      3.000000   35.000000    1.000000    0.000000    1.000000
# max      3.000000  145.000000    8.000000    6.000000    1.000000

# %%
# 위의 코드에서 확인한 결과, Survived 변수의 표준편차는?
0.485011
# Out:
# 0.485011

# %%
# 컬럼별 결측치 비율 확인하기
titanic_df.isna().mean()
# Out:
# Pclass         0.00000
# Name           0.00000
# Gendr          0.00000
# Age            0.00678
# SibSp          0.00000
# Parch          0.00000
# Ticket         0.00000
# Embarked       0.00226
# Survived       0.00000
# ticket_date    0.00000
# dtype: float64

# %%
# 위의 코드에서 확인한 결과, Age 변수의 결측치 비율은?
#0.678%

# %%
# Age 컬럼의 결측치를 평균(mean) 으로 채우기
titanic_df['Age'] = titanic_df['Age'].fillna(titanic_df['Age'].mean())

# %%
# Embarked 컬럼의 결측치를 'S'로 채우기
titanic_df['Embarked'] = titanic_df['Embarked'].fillna('S')

# %%
# Age 컬럼의 아웃라이어를 확인하기 위해, Box Plot 그리기
sns.boxplot(titanic_df['Age'])
# Out:
# /opt/conda/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %%
# Age 컬럼의 아웃라이어를 확인하기 위해, Scatter Plot 그리기 (x축은 인덱스로 설정)
sns.scatterplot(x = titanic_df.index, y = titanic_df['Age'])
# Out:
# <AxesSubplot:ylabel='Age'>

# %%
# Age 컬럼에서 100 이상의 데이터 포인트(데이터 행) 제거하기
titanic_df['Age'] = titanic_df['Age'][titanic_df['Age'] < 100]

# %%
# 변수 이름 "Gendr"를 "Gender"로 변경하기
titanic_df = titanic_df.rename({'Gendr':'Gender'}, axis=1)

# %%
# Gender 변수의 male을 'M'으로, female을 'F'로 변경하기
titanic_df['Gender'] = titanic_df ['Gender'].replace({'male': 'M', 'female': 'F'})

# %%
data.head()
# Out:
#    Pclass  Gender   Age  SibSp  Parch            Ticket Embarked  Survived  \
# 0       3    male  22.0      1      0         A/5 21171        S         0
# 1       1  female  38.0      1      0          PC 17599        C         1
# 2       3  female  26.0      0      0  STON/O2. 3101282        S         1
# 3       1  female  28.0      1      0            113803        S         1
# 4       3    male  35.0      0      0            373450        S         0
#
#   ticket_date  buy_before
# 0  1912-01-12          94
# 1  1912-03-29          17
# 2  1912-02-23          52
# 3  1912-03-28          18
# 4  1912-04-03          12

# %%
# Ticket 변수를 띄어쓰기 기준으로 분류하고, 가장 앞부분을 "ticket_head" 라는 이름의 변수로 저장하기
titanic_df['ticket_head'] = titanic_df['Ticket'].str.split(expand=True)[0]

# %%
# ticket_head 변수를 소문자로 변경하기
titanic_df['ticket_head'] = titanic_df['ticket_head'].str.lower()

# %%
# ticket_date 변수의 데이터 타입을 datetime으로 변경하기
titanic_df['ticket_date'] = pd.to_datetime(titanic_df['ticket_date'])

# %%
# ticket_date 변수에서 year 값을 추출하여 'ticket_year' 컬럼으로 저장하기
titanic_df['ticket_year'] = titanic_df['ticket_date'].dt.year

# %%
titanic_df
# Out:
#      Pclass                                               Name Gender  \
# 0         3                            Braund, Mr. Owen Harris      M
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...      F
# 2         3                             Heikkinen, Miss. Laina      F
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)      F
# 4         3                           Allen, Mr. William Henry      M
# ..      ...                                                ...    ...
# 880       2                              Montvila, Rev. Juozas      M
# 881       1                       Graham, Miss. Margaret Edith      F
# 882       3           Johnston, Miss. Catherine Helen "Carrie"      F
# 883       1                              Behr, Mr. Karl Howell      M
# 884       3                                Dooley, Mr. Patrick      M
#
#            Age  SibSp  Parch            Ticket Embarked  Survived ticket_date  \
# ...
